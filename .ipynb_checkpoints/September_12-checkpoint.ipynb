# %% [markdown]
# # This notebook will help understand what are the effects of the "resolution" and standard deviation of the noise on the wasserstein distance.

# %% [markdown]
# We will look at how increasing the resolution(number of bins) on the same area, increases the wasserstein distance. I would expect the distance to become smaller and to converge to some value.

# %%
import numpy as np
import ot
import matplotlib.pyplot as plt
from utils.Visualizations import *
from ipywidgets import interact, interactive, fixed, interact_manual, FloatSlider
import ipywidgets as widgets
import seaborn as sns
from tqdm import tqdm
# Out:
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
resolution = 100
noise_param = 1e-3
X = np.linspace(0,1,resolution)

p = make_1D_gauss(resolution, np.floor(1 * resolution / 4.), 2.).flatten()
q = make_1D_gauss(resolution, np.floor(5 * resolution / 8.), 2.).flatten()

noise_p = np.random.normal(0, noise_param, resolution)
noise_q = np.random.normal(0, noise_param, resolution)

C = np.zeros([resolution,resolution],dtype=np.float64)
dist_f1 = lambda a,b : abs(a-b)
dist_f2 = lambda a,b : (a-b)**2
for it1 in range(resolution):
    for it2 in range(resolution):
        C[it1,it2] = dist_f1(X[it1],X[it2])

# %%
p_noised = p + noise_p
q_noised = q + noise_q

p_pos, p_neg = split_signed_measure(p_noised)
q_pos, q_neg = split_signed_measure(q_noised)

p_post = p_pos + q_neg
q_post = p_neg + q_pos

# %%
plot_marginals(X, p_post, q_post,'')

# %%
q_post
# Out:
# array([2.34303383e-04, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        1.62173975e-03, 0.00000000e+00, 1.54442782e-03, 0.00000000e+00,
#        0.00000000e+00, 2.93150898e-04, 8.82451631e-04, 0.00000000e+00,
#        1.03824100e-03, 1.75469595e-03, 0.00000000e+00, 1.19499435e-03,
#        9.15980117e-04, 2.21893629e-04, 7.71171871e-04, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 5.04797967e-04, 8.60437319e-04,
#        2.62100217e-04, 1.22767275e-04, 2.05019746e-04, 0.00000000e+00,
#        0.00000000e+00, 1.16628951e-04, 1.90963586e-03, 7.55431167e-04,
#        2.88921497e-04, 0.00000000e+00, 1.80776827e-04, 7.33581980e-04,
#        8.08368381e-04, 0.00000000e+00, 5.61198179e-04, 5.15450635e-04,
#        1.14314122e-03, 3.48724516e-05, 2.29986988e-03, 7.56022762e-04,
#        0.00000000e+00, 4.09025400e-04, 3.07022114e-03, 0.00000000e+00,
#        0.00000000e+00, 3.00440698e-04, 0.00000000e+00, 0.00000000e+00,
#        3.50672031e-04, 1.05724053e-03, 1.08150845e-03, 2.04137886e-03,
#        2.10469168e-03, 9.38387597e-03, 2.73178339e-02, 6.53752862e-02,
#        1.18100697e-01, 1.76997996e-01, 1.98843505e-01, 1.75874142e-01,
#        1.19657152e-01, 6.56981262e-02, 2.54273733e-02, 8.89658960e-03,
#        2.86711449e-03, 8.44702366e-04, 8.25575005e-04, 2.10791151e-03,
#        0.00000000e+00, 0.00000000e+00, 5.22757859e-06, 2.58052858e-03,
#        9.92582416e-04, 7.18642372e-04, 1.88265739e-04, 0.00000000e+00,
#        2.10261918e-03, 0.00000000e+00, 0.00000000e+00, 3.02127916e-03,
#        7.13808414e-04, 1.14689292e-03, 0.00000000e+00, 7.92502448e-04,
#        5.50515782e-04, 1.17217012e-03, 1.61786631e-03, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 4.83566115e-04, 8.68284026e-04,
#        0.00000000e+00, 6.42070470e-04, 0.00000000e+00, 7.60006234e-04])

# %%
def create_distribs(res, noise):
    p = make_1D_gauss(res, np.floor(1 * res / 4.), 2.).flatten()
    q = make_1D_gauss(res, np.floor(5 * res / 8.), 2.).flatten()
    X = np.linspace(0,1,res)

    C = np.zeros([res,res],dtype=np.float64)
    dist_f1 = lambda a,b : abs(a-b)
    dist_f2 = lambda a,b : (a-b)**2
    for it1 in range(res):
        for it2 in range(res):
            C[it1,it2] = dist_f1(X[it1],X[it2])
            
    noise_p = np.random.normal(0, noise, res)
    noise_q = np.random.normal(0, noise, res)

    p_noised = p + noise_p
    q_noised = q + noise_q

    p_pos, p_neg = split_signed_measure(p_noised)
    q_pos, q_neg = split_signed_measure(q_noised)

    p_post = p_pos + q_neg
    q_post = p_neg + q_pos

    return p, q, p_post, q_post, C

# %%
resolutions = np.logspace(2,3,2,base=10, dtype=int)
noise_params = np.logspace(-4,-1,7, dtype=np.float64)

# %%
results_classic = np.zeros([len(resolutions), len(noise_params)], np.float32)
results_noised = np.zeros([len(resolutions), len(noise_params)], np.float32)

# %%
res = 100
noise_param = 5e-2

p, q, p_post, q_post, C = create_distribs(res, noise_param)

results_classic = calc_transport_pot_emd(p, q, C)[1]
plan_noised, log_noised = ot.unbalanced.mm_unbalanced(a = p_post, b = q_post, M = C, reg_m=10, log=True)
results_noised = log_noised['cost']

print('Results on classic EMD:', results_classic)
print('Results on the unbalanced noised:', results_noised)
print(results_classic/results_noised)

print('Results on normal linear:', np.linalg.norm(p-q))
print('Results on unbalanced linear:', np.linalg.norm(p_post-q_post))
print(np.linalg.norm(p-q)/np.linalg.norm(p_post-q_post))
# Out:
# Results on classic EMD: 0.37373737373737376
# Results on the unbalanced noised: 0.31863589098234835
# 1.1729293036799733
# Results on normal linear: 0.5311259660135985
# Results on unbalanced linear: 0.8953558538297713
# 0.5932009756140806

# %%
res = 1000
noise_param = 5e-2
X = np.linspace(0,1,res)

p, q, p_post, q_post, C = create_distribs(res, noise_param)

results_classic = calc_transport_pot_emd(p, q, C)[1]
plan_noised, log_noised = ot.unbalanced.mm_unbalanced(a = p_post, b = q_post, M = C, reg_m=1, log=True)
results_noised = log_noised['cost']

print('Results on classic EMD:', results_classic)
print('Results on the unbalanced noised:', results_noised)
print(results_classic/results_noised)

print('Results on normal linea r:', np.linalg.norm(p-q))
print('Results on unbalanced linear:', np.linalg.norm(p_post-q_post))
print(np.linalg.norm(p-q)/np.linalg.norm(p_post-q_post))
# Out:
# Results on classic EMD: 0.37537537537537546
# Results on the unbalanced noised: 0.35819283292705323
# 1.0479700900431514
# Results on normal linear: 0.5311259660135985
# Results on unbalanced linear: 2.2359533146873187
# 0.23753893362834924

# %%
plot_marginals(X, p_post, q_post, '', first_distribution_title='p_post', second_distribution_title='p')

# %%
plt.plot(p_post)

# %%
plt.plot(p)

# %%
for i, res in tqdm(enumerate(resolutions)):
    for j, noise_param in enumerate(noise_params):
        
        p, q, p_post, q_post, C = create_distribs(res, noise_param)
        
        results_classic[i,j] = calc_transport_pot_emd(p, q, C)[1]
        plan_noised, log_noised = ot.unbalanced.mm_unbalanced(a = p_post, b = q_post, M = C, reg_m=10, log=True)
        results_noised[i,j] = log_noised['cost']
# Out:
# 1it [00:27, 27.48s/it]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[8], line 7
#       4 p, q, p_post, q_post, C = create_distribs(res, noise_param)
#       6 results_classic[i,j] = calc_transport_pot_emd(p, q, C)[1]
# ----> 7 plan_noised, log_noised = ot.unbalanced.mm_unbalanced(a = p_post, b = q_post, M = C, reg_m=10, log=True)
#       8 results_noised[i,j] = log_noised['cost']
#
# File ~\OneDrive\Documents\all_folder\Thesis\Thesis\venv\Lib\site-packages\ot\unbalanced.py:1159, in mm_unbalanced(a, b, M, reg_m, div, G0, numItermax, stopThr, verbose, log)
#    1156     Gd = nx.sum(G, 0, keepdims=True) + nx.sum(G, 1, keepdims=True) + 1e-16
#    1157     G = G * K / Gd
# -> 1159 err = nx.sqrt(nx.sum((G - Gprev) ** 2))
#    1160 if log:
#    1161     log['err'].append(err)
#
# MemoryError: Unable to allocate 7.63 MiB for an array with shape (1000, 1000) and data type float64

# %%
results_noised
# Out:
# array([[0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251],
#        [0.38759251, 0.38759251, 0.38759251, 0.38759251, 0.38759251,
#         0.38759251, 0.38759251]])
