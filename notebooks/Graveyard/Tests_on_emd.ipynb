# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Measures

# %%
df = pd.read_csv('csvs/results_measures.csv')

# %%
df.head()
# Out:
#      Res  Noise_Param  Scale_Param  Distances_Classic  Distances_Noised  \
# 0  100.0     0.001000        100.0           0.299855          0.300037
# 1  100.0     0.001000        200.0           0.299855          0.300261
# 2  100.0     0.001000        500.0           0.299855          0.300433
# 3  100.0     0.001000       1000.0           0.299855          0.299857
# 4  100.0     0.001551        100.0           0.299855          0.300542
#
#    Ratios_EMD  Distances_Linear  Distances_Linear_Noised  Ratios_Linear  \
# 0    0.999546          0.225836                 0.226459       0.997281
# 1    0.998847          0.225836                 0.226225       0.998311
# 2    0.998265          0.225836                 0.226366       0.997693
# 3    1.000160          0.225836                 0.226512       0.997048
# 4    0.998176          0.225836                 0.226823       0.995754
#
#    CI_Distances_Classic  CI_Distances_Noised  Cumsum_Classic  Cumsum_Noised  \
# 0          1.161097e-17             0.000777       29.685607      29.703649
# 1          1.161097e-17             0.000892       29.685607      29.725877
# 2          1.161097e-17             0.000871       29.685607      29.742908
# 3          1.161097e-17             0.000814       29.685607      29.685885
# 4          1.161097e-17             0.001352       29.685607      29.753633
#
#    Ratios_emd_cumsum
# 0           0.010101
# 1           0.010101
# 2           0.010101
# 3           0.010101
# 4           0.010101

# %%
unique_res = df['Res'].unique()
unique_scale = df['Scale_Param'].unique()

# %% [markdown]
# ## Distance vs CumSum
#
# These graphs should show the same thing, not sure why it's not working right now

# %%
fig, axs = plt.subplots(4, 4, figsize=(15, 15))

for i, res_option in enumerate(unique_res):
    for j, scale_option in enumerate(unique_scale):

        # Filter the dataframe based on current 'res' and 'scale' options
        filtered_df = df[(df['Res'] == res_option) & (df['Scale_Param'] == scale_option)]

        ax = axs[i, j]
        ax.plot(filtered_df['Noise_Param'], filtered_df['Distances_Noised'], label='Distance')
        ax.plot(filtered_df['Noise_Param'], filtered_df['Cumsum_Noised'], label='CumSum')
        # ax.set_xscale('log')
        ax.set_title(f'EMD for res={res_option}, scale={scale_option}')
        ax.set_xlabel('Noise')
        ax.set_ylabel('Distance')
        ax.axhline(y=filtered_df['Distances_Classic'].iloc[0], color='r', linestyle='--', label='Emd between original measures')
        ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Ratios Graph
#
# This graph shows how the EMD metric performs better than the linear (Ratios closer to 1 for larger values of noise) throughout different values of res and scale

# %%
fig, axs = plt.subplots(4, 4, figsize=(15, 15))

for i, res_option in enumerate(unique_res):
    for j, scale_option in enumerate(unique_scale):

        # Filter the dataframe based on current 'res' and 'scale' options
        filtered_df = df[(df['Res'] == res_option) & (df['Scale_Param'] == scale_option)]

        ax = axs[i, j]
        ax.plot(filtered_df['Noise_Param'], filtered_df['Ratios_EMD'], label='Distance EMD')
        ax.plot(filtered_df['Noise_Param'], filtered_df['Ratios_Linear'], label='Distance Linear')
        ax.set_xscale('log')
        ax.set_title(f'EMD for res={res_option}, scale={scale_option}')
        ax.set_xlabel('Noise')
        ax.set_ylabel('Ratio')
        ax.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Images

# %%
df = pd.read_csv('csvs/results_images.csv')

# %%
df.head()
# Out:
#    Noise_Param  Distances_Classic  Distances_Noised  Ratios_EMD  \
# 0     0.001000          33.941125         33.979976    0.998858
# 1     0.048571          33.941125         35.772415    0.950429
# 2     0.096143          33.941125         37.253414    0.917385
# 3     0.143714          33.941125         40.296591    0.857230
# 4     0.191286          33.941125         41.250190    0.844509
#
#    Distances_Linear  Distances_Linear_Noised  Ratios_Linear
# 0          2.828427                 2.828466       0.999987
# 1          2.828427                 2.911264       0.972021
# 2          2.828427                 3.141371       0.901809
# 3          2.828427                 3.494957       0.812060
# 4          2.828427                 3.903364       0.727781

# %% [markdown]
# ## Imsize effect

# %%
labels = ['10', '20', '50', '100']

# Split and label
for idx, label in enumerate(labels):
    start_idx = idx * 22
    end_idx = start_idx + 22
    df.loc[start_idx:end_idx-1, 'Im_Size'] = label
# Out:
# C:\Users\eriki\AppData\Local\Temp\ipykernel_5696\1530812326.py:7: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.loc[start_idx:end_idx-1, 'Im_Size'] = label

# %%
df[df['Im_Size'] == '10']
# Out:
#     Noise_Param  Distances_Classic  Distances_Noised  Ratios_EMD  \
# 0      0.001000          33.941125         33.979976    0.998858
# 1      0.048571          33.941125         35.772415    0.950429
# 2      0.096143          33.941125         37.253414    0.917385
# 3      0.143714          33.941125         40.296591    0.857230
# 4      0.191286          33.941125         41.250190    0.844509
# 5      0.238857          33.941125         44.701577    0.782262
# 6      0.286429          33.941125         46.342382    0.753725
# 7      0.334000          33.941125         47.373557    0.742490
# 8      0.381571          33.941125         50.602528    0.695833
# 9      0.429143          33.941125         55.536047    0.638796
# 10     0.476714          33.941125         60.041032    0.589298
# 11     0.524286          33.941125         61.634602    0.572955
# 12     0.571857          33.941125         66.493807    0.534836
# 13     0.619429          33.941125         69.055455    0.510404
# 14     0.667000          33.941125         73.475655    0.480689
# 15     0.714571          33.941125         77.041185    0.455439
# 16     0.762143          33.941125         80.500314    0.435570
# 17     0.809714          33.941125         84.558170    0.412359
# 18     0.857286          33.941125         88.789419    0.396555
# 19     0.904857          33.941125         95.644517    0.364763
# 20     0.952429          33.941125         99.730069    0.352110
# 21     1.000000          33.941125        102.430284    0.344235
#
#     Distances_Linear  Distances_Linear_Noised  Ratios_Linear Im_Size
# 0           2.828427                 2.828466       0.999987      10
# 1           2.828427                 2.911264       0.972021      10
# 2           2.828427                 3.141371       0.901809      10
# 3           2.828427                 3.494957       0.812060      10
# 4           2.828427                 3.903364       0.727781      10
# 5           2.828427                 4.486400       0.632560      10
# 6           2.828427                 4.937379       0.574808      10
# 7           2.828427                 5.429501       0.523424      10
# 8           2.828427                 6.023989       0.471820      10
# 9           2.828427                 6.747137       0.421341      10
# 10          2.828427                 7.325180       0.388170      10
# 11          2.828427                 7.909265       0.359334      10
# 12          2.828427                 8.580498       0.330937      10
# 13          2.828427                 9.151740       0.310645      10
# 14          2.828427                 9.822227       0.289229      10
# 15          2.828427                10.469752       0.271365      10
# 16          2.828427                11.085353       0.256196      10
# 17          2.828427                11.818006       0.240348      10
# 18          2.828427                12.328288       0.230574      10
# 19          2.828427                13.080002       0.217237      10
# 20          2.828427                13.881066       0.204694      10
# 21          2.828427                14.383309       0.197912      10

# %%
labels
# Out:
# ['10', '20', '50', '100']

# %%
for idx, im_size_val in enumerate(labels):
    print(idx)
# Out:
# 0
# 1
# 2
# 3

# %%
fig, axs = plt.subplots(1, 4, figsize=(20, 5))
axs = axs.ravel()

for idx, im_size_val in enumerate(labels):
    ax = axs[idx]
    
    filtered_df = df[df['Im_Size'] == im_size_val]

    ax.plot(filtered_df['Noise_Param'], filtered_df['Ratios_EMD'], label='Ratio EMD')
    ax.plot(filtered_df['Noise_Param'], filtered_df['Ratios_Linear'], label='Ratio Linear')
    ax.set_xscale('log')
    ax.set_title(f'EMD for im_size={im_size_val}')
    ax.set_xlabel('Noise')
    ax.set_ylabel('Ratio')
    ax.legend()

plt.tight_layout()
plt.show()
